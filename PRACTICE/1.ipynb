# %%
import pandas as pd
booli = pd.read_csv(r'C:\Users\sebas\OneDrive\UNIVERSITY\HT 24\MT4007 - statistical data processing\PRACTICE\Booli_sold.csv')
booli.isna().sum()
# Out:
# listPrice                             0
# rent                                  2
# livingArea                            1
# rooms                                 1
# published                             0
# constructionYear                     14
# objectType                            0
# booliId                               0
# soldDate                              0
# soldPrice                             0
# soldPriceSource                       0
# url                                   0
# floor                                40
# additionalArea                      130
# apartmentNumber                      92
# plotArea                            144
# location.address.streetAddress        0
# location.position.latitude            0
# location.position.longitude           0
# location.position.isApproximate      46
# location.region.municipalityName      0
# location.region.countyName            0
# location.distance.ocean               0
# ...

# %%
booli["ppsqm"] = booli["soldPrice"] / booli["livingArea"]
booli["ppsqm"].nlargest(5)
# Out:
# 67    104166.666667
# 50    102083.333333
# 54    100000.000000
# 34     88400.000000
# 55     85501.858736
# Name: ppsqm, dtype: float64

# %%
mean_ppsqm = booli["ppsqm"].mean()
mean_ppsqm
# Out:
# np.float64(58759.382760081724)

# %%
election = pd.read_csv(r'C:\Users\sebas\OneDrive\UNIVERSITY\HT 24\MT4007 - statistical data processing\PRACTICE\2018_R_per_kommun.csv', sep = ";",  decimal = ",")

# %%
stockholm_votes = election[election["KOMMUNNAMN"] == "Stockholm"]
stockholm_legitimate_votes = stockholm_votes["RÖSTER GILTIGA"].sum()
stockholm_legitimate_votes
# Out:
# np.int64(611206)

# %%
top_social_democrats = election["S"].nlargest(5)
top_social_democrats
# Out:
# 188    52.18
# 286    47.48
# 196    47.46
# 279    46.68
# 280    45.37
# Name: S, dtype: float64

# %%
top_participation = election["VALDELTAGANDE"].nlargest(3)
top_participation
# Out:
# 103    93.86
# 59     93.35
# 98     93.13
# Name: VALDELTAGANDE, dtype: float64

# %%
strokes = pd.read_csv(r'C:\Users\sebas\OneDrive\UNIVERSITY\HT 24\MT4007 - statistical data processing\PRACTICE\stroke-data.csv')

# %%
strokes = strokes[['gender', 'age', 'smoking_status', 'heart_disease', 'bmi', 'stroke']]

strokes["bmi"].fillna(strokes["bmi"].mean(), inplace = True)

strokes["gender"] = strokes["gender"].map({
    'Male': 0, 
    'Female': 1, 
    'Other': 2
})

strokes['smoking_status'] = strokes['smoking_status'].map({
    'never smoked': 0,
    'formerly smoked': 1,
    'smokes': 2,
    'Unknown': 3
})


corr_matrix = strokes.corr()
corr_matrix

import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_20768\105471503.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   strokes["bmi"].fillna(strokes["bmi"].mean(), inplace = True)
